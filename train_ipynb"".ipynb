# %% [markdown]
# <a href="https://colab.research.google.com/github/Tat-Khurtina/VTB-cnn/blob/main/train_ipynb%22%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.models as models
import torchvision.transforms as transforms

import time
import os
import PIL.Image as Image
from IPython.display import display

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
print(torch.cuda.get_device_name(device))
# Out:
# cuda:0
# Tesla T4

# %%
# ВНИМАНИЕ; версия Pillow установвленна по умолчанию - '7.0.0'
# Эта версия ломает torchvision
import PIL
PIL.__version__
# Out:
# '5.3.0'

# %%
# !pip uninstall -y Pillow
# !pip install -Iv Pillow==5.3.0

# %%
# !pip install -U torch torchvision
# Out:
# Requirement already up-to-date: torch in /usr/local/lib/python3.6/dist-packages (1.6.0+cu101)
# Requirement already up-to-date: torchvision in /usr/local/lib/python3.6/dist-packages (0.7.0+cu101)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#####1
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/train/Hyundai Solaris sedan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')

# %%
#####2
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/train/KIA Rio sedan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')

# %%
#####3
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/train/SKODA OCTAVIA sedan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/SKODA OCTAVIA sedan/Копия 679.jpg

# %%
#####4
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan/Копия 266.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan/Копия 274.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan/Копия 273.jpg
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan/Копия 367.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan/Копия 361.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan/Копия 397.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan/Копия 482.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Polo sedan/Копия 486.jpg
# ...

# %%
#####5
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/train/Volkswagen Tiguan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Cannot load : /content/drive/My Drive/new_car0/cartt/train/Volkswagen Tiguan/Копия 413.jpg

# %%
#####1t

for p in Path(f'/content/drive/My Drive/new_car0/cartt/test/Hyundai Solaris sedan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))

# %%
#####2t
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/test/KIA Rio sedan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/KIA Rio sedan/Копия 136.jpg
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')

# %%
#####3t
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/test/SKODA OCTAVIA sedan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/SKODA OCTAVIA sedan/Копия 219.jpg

# %%
#####4t
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 206.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 213.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 191.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 173.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 179.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 184.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 153.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 37.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 40.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Polo sedan/Копия 69.jpg
# ...

# %%
#####5t
from PIL import Image
from pathlib import Path
for p in Path(f'/content/drive/My Drive/new_car0/cartt/test/Volkswagen Tiguan').glob('*.jpg'):
  try:
    im = Image.open(p)
    im2 = im.convert('RGB')
  except OSError:
    print("Cannot load : {}".format(p))
    os.remove(format(p))
# Out:
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Tiguan/Копия 14.jpg
# Cannot load : /content/drive/My Drive/new_car0/cartt/test/Volkswagen Tiguan/Копия 232.jpg

# %%
dataset_dir = "/content/drive/My Drive/new_car0/cartt/"

train_tfms = transforms.Compose([transforms.Resize((400, 400)),
                                 transforms.RandomHorizontalFlip(),
                                 transforms.RandomRotation(15),
                                 transforms.ToTensor(),
                                 transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
test_tfms = transforms.Compose([transforms.Resize((400, 400)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

dataset = torchvision.datasets.ImageFolder(root=dataset_dir+"train", transform = train_tfms)
trainloader = torch.utils.data.DataLoader(dataset, batch_size = 32, shuffle=True, num_workers = 2)

dataset2 = torchvision.datasets.ImageFolder(root=dataset_dir+"test", transform = test_tfms)
testloader = torch.utils.data.DataLoader(dataset2, batch_size = 32, shuffle=False, num_workers = 2)

# %%
def train_model(model, criterion, optimizer, scheduler, n_epochs = 5):
    
    losses = []
    accuracies = []
    test_accuracies = []
    # set the model to train mode initially
    model.train()
    for epoch in range(n_epochs):
        since = time.time()
        running_loss = 0.0
        running_correct = 0.0
        for i, data in enumerate(trainloader, 0):

            # get the inputs and assign them to cuda
            inputs, labels = data
            #inputs = inputs.to(device).half() # uncomment for half precision model
            inputs = inputs.to(device)
            labels = labels.to(device)
            optimizer.zero_grad()
            
            # forward + backward + optimize
            outputs = model(inputs)
            _, predicted = torch.max(outputs.data, 1)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            
            # calculate the loss/acc later
            running_loss += loss.item()
            running_correct += (labels==predicted).sum().item()

        epoch_duration = time.time()-since
        epoch_loss = running_loss/len(trainloader)
        epoch_acc = 100/32*running_correct/len(trainloader)
        print("Epoch %s, duration: %d s, loss: %.4f, acc: %.4f" % (epoch+1, epoch_duration, epoch_loss, epoch_acc))
        
        losses.append(epoch_loss)
        accuracies.append(epoch_acc)
        
        # switch the model to eval mode to evaluate on test data
        model.eval()
        test_acc = eval_model(model)
        test_accuracies.append(test_acc)
        
        # re-set the model to train mode after validating
        model.train()
        scheduler.step(test_acc)
        since = time.time()
    print('Finished Training')
    return model, losses, accuracies, test_accuracies

# %%
def eval_model(model):
    correct = 0.0
    total = 0.0
    with torch.no_grad():
        for i, data in enumerate(testloader, 0):
            images, labels = data
            #images = images.to(device).half() # uncomment for half precision model
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model_ft(images)
            _, predicted = torch.max(outputs.data, 1)
            
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    test_acc = 100.0 * correct / total
    print('Accuracy of the network on the test images: %d %%' % (
        test_acc))
    return test_acc

# %%
model_ft = models.resnet34(pretrained=True)
num_ftrs = model_ft.fc.in_features

# replace the last fc layer with an untrained one (requires grad by default)
model_ft.fc = nn.Linear(num_ftrs, 196)
model_ft = model_ft.to(device)

# uncomment this block for half precision model
"""
model_ft = model_ft.half()


for layer in model_ft.modules():
    if isinstance(layer, nn.BatchNorm2d):
        layer.float()
"""
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model_ft.parameters(), lr=0.01, momentum=0.9)

"""
probably not the best metric to track, but we are tracking the training accuracy and measuring whether
it increases by atleast 0.9 per epoch and if it hasn't increased by 0.9 reduce the lr by 0.1x.
However in this model it did not benefit me.
"""
lrscheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='max', patience=3, threshold = 0.9)

# %%
model_ft, training_losses, training_accs, test_accs = train_model(model_ft, criterion, optimizer, lrscheduler, n_epochs=10)
# Out:
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Epoch 1, duration: 267 s, loss: 0.6317, acc: 78.4821
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# Accuracy of the network on the test images: 85 %
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
# ...

# %%
from matplotlib import colors, pyplot as plt
# %matplotlib inline

# %%
f, axarr = plt.subplots(2,2, figsize = (12, 8))
axarr[0, 0].plot(training_losses)
axarr[0, 0].set_title("Training loss")
axarr[0, 1].plot(training_accs)
axarr[0, 1].set_title("Training acc")
axarr[1, 0].plot(test_accs)

axarr[1, 0].set_title("Test acc")
# Out:
# Text(0.5, 1.0, 'Test acc')

# %%
def find_classes(dir):
    classes = os.listdir(dir)
    classes.sort()
    class_to_idx = {classes[i]: i for i in range(len(classes))}
    return classes, class_to_idx
classes, c_to_idx = find_classes(dataset_dir+"train")

# %%
classes
# Out:
# ['Hyundai Solaris sedan',
#  'KIA Rio sedan',
#  'SKODA OCTAVIA sedan',
#  'Volkswagen Polo sedan',
#  'Volkswagen Tiguan']

# %%
c_to_idx
# Out:
# {'Hyundai Solaris sedan': 0,
#  'KIA Rio sedan': 1,
#  'SKODA OCTAVIA sedan': 2,
#  'Volkswagen Polo sedan': 3,
#  'Volkswagen Tiguan': 4}

# %%
model_ft.eval()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
import time

# %%
start_time = time.time()
loader = transforms.Compose([transforms.Resize((400, 400)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
image = Image.open('/content/4433098_101.jpg')
image = loader(image).float()
image = torch.autograd.Variable(image, requires_grad=True)
image = image.unsqueeze(0)
image = image.cuda()
output = model_ft(image)
conf, predicted = torch.max(output.data, 1)
display(Image.open('/content/4433098_101.jpg'))
print(classes[predicted.item()], "confidence: ", conf.item())
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x576 at 0x7F9F70184438>
# Volkswagen Polo sedan confidence:  26.66469383239746
# --- 0.22423171997070312 seconds ---

# %%
start_time = time.time()
loader = transforms.Compose([transforms.Resize((400, 400)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
image = Image.open('/content/777_d_850.jpg')
image = loader(image).float()
image = torch.autograd.Variable(image, requires_grad=True)
image = image.unsqueeze(0)
image = image.cuda()
output = model_ft(image)
conf, predicted = torch.max(output.data, 1)
display(Image.open('/content/777_d_850.jpg'))
print(classes[predicted.item()], "confidence: ", conf.item())
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x667 at 0x7F9F70184E80>
# Volkswagen Polo sedan confidence:  18.63990592956543
# --- 0.30091285705566406 seconds ---

# %%
start_time = time.time()
loader = transforms.Compose([transforms.Resize((400, 400)),
                                transforms.ToTensor(),
                                transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
image = Image.open('/content/500000_volkswagen_polo_2_1_.jpg')
image = loader(image).float()
image = torch.autograd.Variable(image, requires_grad=True)
image = image.unsqueeze(0)
image = image.cuda()
output = model_ft(image)
conf, predicted = torch.max(output.data, 1)
display(Image.open('/content/500000_volkswagen_polo_2_1_.jpg'))
print(classes[predicted.item()], "confidence: ", conf.item())
print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x422 at 0x7F9F70184FD0>
# Volkswagen Polo sedan confidence:  24.163148880004883
# --- 0.15949082374572754 seconds ---

# %%
# Saving: feature weights, new model.fc, index-to-class mapping, optimiser state, and No. of epochs
checkpoint = {'state_dict': model_ft.state_dict(),
              'model': model_ft.fc,
              'class_to_idx': dataset.class_to_idx,
              'opt_state': optimizer.state_dict,
              'num_epochs': 10}

torch.save(checkpoint, '/content/drive/My Drive/new_car0/5mod.pth')

# %%
dataset.class_to_idx
# Out:
# {'Hyundai Solaris sedan': 0,
#  'KIA Rio sedan': 1,
#  'SKODA OCTAVIA sedan': 2,
#  'Volkswagen Polo sedan': 3,
#  'Volkswagen Tiguan': 4}
